# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0         True
# 1     35            20000          0         True
# 2     26            43000          0        False
# 3     27            57000          0        False
# 4     19            76000          0         True
# ..   ...              ...        ...          ...
# 395   46            41000          1        False
# 396   51            23000          1         True
# 397   50            20000          1        False
# 398   36            33000          0         True
# 399   49            36000          1        False
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
param_grid = {
    'n_estimators': [100, 200, 300],             
    'max_features': ['sqrt', 'log2'],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [None,100],     
    'min_samples_split': [2],             
    'min_samples_leaf': [1],               
    'bootstrap': [True, False] }                
rf = RandomForestClassifier()
grid = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=3, scoring='accuracy')
grid.fit(indep, dep)
print("Best parameters found: ", grid.best_params_)
print("Best cross-validation score: {:.2f}".format(grid.best_score_))
best_rf = grid.best_estimator_
y_pred = best_rf.predict(indep)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best parameters found:  {'bootstrap': True, 'criterion': 'log_loss', 'max_depth': 100, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best cross-validation score: 0.86

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(dep, y_pred)
print(cm)
# Out:
# [[256   1]
#  [  0 143]]

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(dep, y_pred)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       257
#            1       0.99      1.00      1.00       143
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %%
print(cm)
# Out:
# [[256   1]
#  [  0 143]]

# %%
grid.predict([[27,57000,0]])
# Out:
# C:\Users\swath\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        1.119324      0.316523         0.050479        0.037606
# 1        2.395410      0.721604         0.085688        0.025435
# 2        3.719226      1.032343         0.168054        0.041642
# 3        1.281015      0.167165         0.053200        0.035805
# 4        2.276773      0.751876         0.067262        0.039502
# ..            ...           ...              ...             ...
# 67       2.170562      0.403621         0.086640        0.039763
# 68       3.140406      0.759261         0.136921        0.057981
# 69       1.176771      0.029015         0.057524        0.038552
# 70       2.292443      0.075280         0.093098        0.031981
# 71       2.636609      0.306736         0.086656        0.007357
#
#    param_bootstrap param_criterion param_max_depth param_max_features  \
# 0             True            gini            None               sqrt
# 1             True            gini            None               sqrt
# 2             True            gini            None               sqrt
# 3             True            gini            None               log2
# 4             True            gini            None               log2
# ..             ...             ...             ...                ...
# 67           False        log_loss             100               sqrt
# 68           False        log_loss             100               sqrt
# 69           False        log_loss             100               log2
# 70           False        log_loss             100               log2
# 71           False        log_loss             100               log2
#
#    param_min_samples_leaf param_min_samples_split param_n_estimators  \
# 0                       1                       2                100
# 1                       1                       2                200
# 2                       1                       2                300
# 3                       1                       2                100
# 4                       1                       2                200
# ..                    ...                     ...                ...
# 67                      1                       2                200
# 68                      1                       2                300
# 69                      1                       2                100
# 70                      1                       2                200
# 71                      1                       2                300
#
#                                                params  split0_test_score  \
# 0   {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7875
# 1   {'bootstrap': True, 'criterion': 'gini', 'max_...             0.8000
# 2   {'bootstrap': True, 'criterion': 'gini', 'max_...             0.7875
# 3   {'bootstrap': True, 'criterion': 'gini', 'max_...             0.8000
# 4   {'bootstrap': True, 'criterion': 'gini', 'max_...             0.8000
# ..                                                ...                ...
# 67  {'bootstrap': False, 'criterion': 'log_loss', ...             0.7875
# 68  {'bootstrap': False, 'criterion': 'log_loss', ...             0.7875
# 69  {'bootstrap': False, 'criterion': 'log_loss', ...             0.7875
# 70  {'bootstrap': False, 'criterion': 'log_loss', ...             0.7875
# 71  {'bootstrap': False, 'criterion': 'log_loss', ...             0.7875
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0              0.9375             0.8750             0.8375
# 1              0.9375             0.8750             0.8375
# 2              0.9250             0.8750             0.8375
# 3              0.9375             0.8750             0.8375
# 4              0.9375             0.8750             0.8375
# ..                ...                ...                ...
# 67             0.9125             0.8625             0.8125
# 68             0.9125             0.8750             0.8125
# 69             0.9125             0.8625             0.8125
# 70             0.9125             0.8625             0.8125
# 71             0.9125             0.8750             0.8125
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.7750           0.8425        0.059477               31
# 1              0.7750           0.8450        0.057337               19
# 2              0.8000           0.8450        0.050374               19
# 3              0.8000           0.8500        0.051841                5
# 4              0.8000           0.8500        0.051841                5
# ..                ...              ...             ...              ...
# 67             0.7625           0.8275        0.053852               47
# 68             0.7750           0.8325        0.052797               37
# 69             0.7750           0.8300        0.050990               38
# 70             0.7500           0.8250        0.057009               63
# 71             0.7625           0.8300        0.055678               38
#
# [72 rows x 20 columns]
